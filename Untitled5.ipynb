# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np

# %%
data ={
    "age":[25,30, 35,np.nan, 40 , 50],
    "Salary":[50000, 60000, np.nan, 45000, 80000, 52000],
    "city":["Mumbai", "Delhi", "Pune", np.nan, "Mumbai"],
    "gender":["Male", "Female", "Female", "Male", "Female", np.nan],
    "purchased":[1, 0, 0, 1, 1, 0]
}

# %%
data ={
    "age":[25,30, 35,np.nan, 40 , 50],
    "Salary":[50000, 60000, np.nan, 45000, 80000, 52000],
    "city":["Mumbai", "Delhi", "Pune", np.nan, "Mumbai", np.nan],
    "gender":["Male", "Female", "Female", "Male", "Female", np.nan],
    "purchased":[1, 0, 0, 1, 1, 0]
}
df= pd.DataFrame(data)
print(df)
x= df.drop("purchased", axis=1)
y= df["purchased"]
# Out:
#     age   Salary    city  gender  purchased
# 0  25.0  50000.0  Mumbai    Male          1
# 1  30.0  60000.0   Delhi  Female          0
# 2  35.0      NaN    Pune  Female          0
# 3   NaN  45000.0     NaN    Male          1
# 4  40.0  80000.0  Mumbai  Female          1
# 5  50.0  52000.0     NaN     NaN          0
